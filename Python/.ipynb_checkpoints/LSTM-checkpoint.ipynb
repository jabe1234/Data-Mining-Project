# %% [markdown]
# Long Short Term Memory

# %% [markdown]
# [Code Example](https://www.geeksforgeeks.org/long-short-term-memory-lstm-rnn-in-tensorflow/)
#
# [Concept Explaination](https://www.simplilearn.com/tutorials/artificial-intelligence-tutorial/lstm)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

from statsmodels.tsa.seasonal import seasonal_decompose

from sklearn.preprocessing import MinMaxScaler

from keras.preprocessing.sequence import TimeseriesGenerator

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.losses import Huber

# %%
def runModel(cases, num_features, loss_function):
    # results = seasonal_decompose(cases)
    # results.plot()
    
    train = cases.iloc[:120]
    test = cases.iloc[120:]

    array = train.to_numpy()
    array.reshape(-1, 1)
    train = pd.DataFrame(array)

    array = test.to_numpy()
    array.reshape(-1, 1)
    test = pd.DataFrame(array)
    
    scaler = MinMaxScaler()
    scaler.fit(train)
    scaled_train = scaler.transform(train)
    scaled_test = scaler.transform(test)
     
    n_input = 3
    n_features = num_features
    generator = TimeseriesGenerator(scaled_train,
                                    scaled_train,
                                    length=n_input,
                                    batch_size=1)
    X, y = generator[0]
    print(f'Given the Array: \n{X.flatten()}')
    print(f'Predict this y: \n {y}')
    # We do the same thing, but now instead for 12 months
    n_input = 12
    generator = TimeseriesGenerator(scaled_train,
                                    scaled_train,
                                    length=n_input,
                                    batch_size=1)
    
    # define model
    model = Sequential()
    model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(n_input, n_features)))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(LSTM(50, activation='relu', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(LSTM(25, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss=loss_function, metrics=[loss_function])
    model.summary()
    model.fit(generator, epochs=15)

# %%
vaccinations = pd.read_csv('./../Data/Final_Datasets/country_vaccinations.csv')

vaccinations = vaccinations[vaccinations['country'] == 'United States']

# print(vaccinations)

period_start = vaccinations.iloc[0]['date']
period_end = vaccinations.iloc[len(vaccinations) - 1]['date']

# %%
cases = pd.read_csv('./../Data/Final_Datasets/country_death_case.csv',
                 index_col='Date_reported',
                 parse_dates=True)

cases = cases[cases['Country'] == 'United States of America']
# trim the cases to the dates of the vaccinations
cases = cases.loc[period_start:period_end]
cases = cases['New_cases']
# print(cases)
# cases.index.freq = 'MS'
# Out:
# Date_reported
# 2020-12-13    245839.0
# 2020-12-14    217153.0
# 2020-12-15    181275.0
# 2020-12-16    198204.0
# 2020-12-17    198650.0
#                 ...
# 2022-03-24     24771.0
# 2022-03-25     45160.0
# 2022-03-26     36077.0
# 2022-03-27     28714.0
# 2022-03-28     12511.0
# Name: New_cases, Length: 471, dtype: float64

# %%
# shift cases forward by gap_size while keeping data the same size
def applyGap(gap_size, cases, vaccinations):
    if gap_size <=0:
        return (cases, vaccinations)
    gap_cases = cases.iloc[gap_size:]
    gap_vaccinations = vaccinations.iloc[:-gap_size] 
    return (gap_cases, gap_vaccinations)

# %%
cases, vaccinations = applyGap(14, cases, vaccinations)

# %%
# Plotting graph b/w production and date
cases.plot(figsize=(12, 6))
# Out:
# <AxesSubplot: xlabel='Date_reported'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
results = seasonal_decompose(cases)
results.plot()

# %%
train = cases.iloc[:300]
test = cases.iloc[300:]

array = train.to_numpy()
array.reshape(-1, 1)
train = pd.DataFrame(array)

array = test.to_numpy()
array.reshape(-1, 1)
test = pd.DataFrame(array)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
 
n_input = 3
n_features = 1
generator = TimeseriesGenerator(scaled_train,
                                scaled_train,
                                length=n_input,
                                batch_size=1)
X, y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# We do the same thing, but now instead for 12 months
n_input = 12
generator = TimeseriesGenerator(scaled_train,
                                scaled_train,
                                length=n_input,
                                batch_size=1)
# Out:
# Given the Array:
# [0.95665216 0.83039524 0.70386898]
# Predict this y:
#  [[0.67237737]]

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(n_input, n_features)))
model.add(Dropout(0.3))
model.add(LSTM(50, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
model.fit(generator, epochs=5)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_26 (LSTM)              (None, 12, 100)           40800
#
#  dropout_12 (Dropout)        (None, 12, 100)           0
#
#  lstm_27 (LSTM)              (None, 50)                30200
#
#  batch_normalization_12 (Bat  (None, 50)               200
#  chNormalization)
#
#  dense_14 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 71,251
# Trainable params: 71,151
# Non-trainable params: 100
# _________________________________________________________________
# Epoch 1/5
# 288/288 [==============================] - 5s 9ms/step - loss: 0.0647 - mae: 0.2060
# Epoch 2/5
# 288/288 [==============================] - 2s 8ms/step - loss: 0.0595 - mae: 0.1960
# Epoch 3/5
# 288/288 [==============================] - 2s 8ms/step - loss: 0.0600 - mae: 0.1982
# Epoch 4/5
# 288/288 [==============================] - 2s 8ms/step - loss: 0.0591 - mae: 0.1951
# Epoch 5/5
# 288/288 [==============================] - 2s 9ms/step - loss: 0.0599 - mae: 0.1960

# %% [markdown]
# Now try with Vaccination data included in the regression

# %%
vaccinations = pd.read_csv('./../Data/Final_Datasets/country_vaccinations.csv')

vaccinations = vaccinations[vaccinations['country'] == 'United States']

# print(vaccinations)

period_start = vaccinations.iloc[0]['date']
period_end = vaccinations.iloc[len(vaccinations) - 1]['date']

cases = pd.read_csv('./../Data/Final_Datasets/country_death_case.csv',
                 index_col='Date_reported',
                 parse_dates=True)

cases = cases[cases['Country'] == 'United States of America']
# trim the cases to the dates of the vaccinations
cases = cases.loc[period_start:period_end]
cases = cases['New_cases']
cases = pd.DataFrame(cases)
cases.insert(1, "daily_vaccinations", vaccinations["daily_vaccinations"].tolist(), True)
print(cases)
# Out:
#                New_cases  daily_vaccinations
# Date_reported
# 2021-01-10       48105.0                 0.0
# 2021-01-11       40035.0            165844.0
# 2021-01-12       37174.0            194785.0
# 2021-01-13       58592.0            226086.0
# 2021-01-14       50647.0            250052.0
# ...                  ...                 ...
# 2022-03-24       99095.0             34110.0
# 2022-03-25       94185.0             33823.0
# 2022-03-26       82905.0             33398.0
# 2022-03-27       72430.0             32769.0
# 2022-03-28       61456.0             32275.0
#
# [443 rows x 2 columns]

# %%
train = cases.iloc[:300]
test = cases.iloc[300:]

array = train.to_numpy()
array.reshape(-1, 1)
train = pd.DataFrame(array)

array = test.to_numpy()
array.reshape(-1, 1)
test = pd.DataFrame(array)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
 
n_input = 3
n_features = 2
generator = TimeseriesGenerator(scaled_train,
                                scaled_train,
                                length=n_input,
                                batch_size=1)
X, y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# We do the same thing, but now instead for 12 months
n_input = 12
generator = TimeseriesGenerator(scaled_train,
                                scaled_train,
                                length=n_input,
                                batch_size=1)
# Out:
# Given the Array:
# [0.77058464 0.         0.63734377 0.2753667  0.59010682 0.32342022]
# Predict this y:
#  [[0.94373174 0.37539227]]

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(n_input, n_features)))
model.add(Dropout(0.3))
model.add(LSTM(50, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
model.fit(generator, epochs=5)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_28 (LSTM)              (None, 12, 100)           41200
#
#  dropout_13 (Dropout)        (None, 12, 100)           0
#
#  lstm_29 (LSTM)              (None, 50)                30200
#
#  batch_normalization_13 (Bat  (None, 50)               200
#  chNormalization)
#
#  dense_15 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 71,651
# Trainable params: 71,551
# Non-trainable params: 100
# _________________________________________________________________
# Epoch 1/5
# 288/288 [==============================] - 5s 9ms/step - loss: 0.0887 - mae: 0.2487
# Epoch 2/5
# 288/288 [==============================] - 3s 9ms/step - loss: 0.0788 - mae: 0.2398
# Epoch 3/5
# 288/288 [==============================] - 3s 9ms/step - loss: 0.0791 - mae: 0.2393
# Epoch 4/5
# 288/288 [==============================] - 2s 9ms/step - loss: 0.0788 - mae: 0.2383
# Epoch 5/5
# 288/288 [==============================] - 3s 9ms/step - loss: 0.0786 - mae: 0.2397

# %%
runModel(cases)
# Out:
# Given the Array:
# [0.53929112 0.48918014 0.51462847]
# Predict this y:
#  [[0.5936617]]
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 12, 100)           40800
#
#  dropout_14 (Dropout)        (None, 12, 100)           0
#
#  lstm_31 (LSTM)              (None, 50)                30200
#
#  batch_normalization_14 (Bat  (None, 50)               200
#  chNormalization)
#
#  dense_16 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 71,251
# Trainable params: 71,151
# Non-trainable params: 100
# _________________________________________________________________
# Epoch 1/5
# 288/288 [==============================] - 5s 8ms/step - loss: 0.0450 - mae: 0.1711
# Epoch 2/5
# 288/288 [==============================] - 2s 8ms/step - loss: 0.0436 - mae: 0.1676
# Epoch 3/5
# 288/288 [==============================] - 2s 7ms/step - loss: 0.0438 - mae: 0.1684
# Epoch 4/5
# 288/288 [==============================] - 2s 8ms/step - loss: 0.0431 - mae: 0.1679
# Epoch 5/5
# 288/288 [==============================] - 2s 9ms/step - loss: 0.0435 - mae: 0.1682

# %%
vaccinations = pd.read_csv('./../Data/Final_Datasets/country_vaccinations.csv')

vaccinations = vaccinations[vaccinations['country'] == 'United States']

# print(vaccinations)

period_start = vaccinations.iloc[0]['date']
period_end = vaccinations.iloc[len(vaccinations) - 1]['date']

cases = pd.read_csv('./../Data/Final_Datasets/country_death_case.csv',
                 index_col='Date_reported',
                 parse_dates=True)

cases = cases[cases['Country'] == 'United States of America']
# trim the cases to the dates of the vaccinations
cases = cases.loc[period_start:period_end]
cases = cases['New_cases']
# print(cases)
# cases.index.freq = 'MS'

# cases = cases.tail(150)

# %%
# Run the model with no shift applied
runModel(cases, 1, 'mse')
# Out:
# Given the Array:
# [0.81449227 0.69947314 0.55561704]
# Predict this y:
#  [[0.6234954]]
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_93 (LSTM)              (None, 12, 100)           40800
#
#  dropout_60 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_60 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_94 (LSTM)              (None, 12, 50)            30200
#
#  dropout_61 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_61 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_95 (LSTM)              (None, 25)                7600
#
#  dense_32 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,226
# Trainable params: 78,926
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 5s 14ms/step - loss: 0.0928 - mse: 0.0928
# Epoch 2/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0355 - mse: 0.0355
# Epoch 3/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0249 - mse: 0.0249
# Epoch 4/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0196 - mse: 0.0196
# Epoch 5/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0158 - mse: 0.0158
# Epoch 6/15
# 108/108 [==============================] - 1s 14ms/step - loss: 0.0101 - mse: 0.0101
# Epoch 7/15
# 108/108 [==============================] - 1s 14ms/step - loss: 0.0210 - mse: 0.0210
# Epoch 8/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0168 - mse: 0.0168
# Epoch 9/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0205 - mse: 0.0205
# Epoch 10/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0113 - mse: 0.0113
# Epoch 11/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0139 - mse: 0.0139
# Epoch 12/15
# 108/108 [==============================] - 2s 14ms/step - loss: 0.0131 - mse: 0.0131
# Epoch 13/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0109 - mse: 0.0109
# Epoch 14/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0131 - mse: 0.0131
# Epoch 15/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0113 - mse: 0.0113

# %%
runModel(cases, 1, 'mae')
# Out:
# Given the Array:
# [0.81449227 0.69947314 0.55561704]
# Predict this y:
#  [[0.6234954]]
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_96 (LSTM)              (None, 12, 100)           40800
#
#  dropout_62 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_62 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_97 (LSTM)              (None, 12, 50)            30200
#
#  dropout_63 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_63 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_98 (LSTM)              (None, 25)                7600
#
#  dense_33 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,226
# Trainable params: 78,926
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 5s 14ms/step - loss: 0.1816 - mae: 0.1816
# Epoch 2/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1388 - mae: 0.1388
# Epoch 3/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0997 - mae: 0.0997
# Epoch 4/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0870 - mae: 0.0870
# Epoch 5/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0793 - mae: 0.0793
# Epoch 6/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0753 - mae: 0.0753
# Epoch 7/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0849 - mae: 0.0849
# Epoch 8/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0740 - mae: 0.0740
# Epoch 9/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0795 - mae: 0.0795
# Epoch 10/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0689 - mae: 0.0689
# Epoch 11/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0798 - mae: 0.0798
# Epoch 12/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0749 - mae: 0.0749
# Epoch 13/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0610 - mae: 0.0610
# Epoch 14/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0709 - mae: 0.0709
# Epoch 15/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0579 - mae: 0.0579

# %%
runModel(cases, 1, Huber())
# Out:
# Given the Array:
# [0.81449227 0.69947314 0.55561704]
# Predict this y:
#  [[0.6234954]]
# Model: "sequential_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_105 (LSTM)             (None, 12, 100)           40800
#
#  dropout_68 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_68 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_106 (LSTM)             (None, 12, 50)            30200
#
#  dropout_69 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_69 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_107 (LSTM)             (None, 25)                7600
#
#  dense_36 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,226
# Trainable params: 78,926
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 5s 15ms/step - loss: 0.0506 - huber_loss: 0.0506
# Epoch 2/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0207 - huber_loss: 0.0207
# Epoch 3/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0113 - huber_loss: 0.0113
# Epoch 4/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0133 - huber_loss: 0.0133
# Epoch 5/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0114 - huber_loss: 0.0114
# Epoch 6/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0064 - huber_loss: 0.0064
# Epoch 7/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0059 - huber_loss: 0.0059
# Epoch 8/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0066 - huber_loss: 0.0066
# Epoch 9/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0081 - huber_loss: 0.0081
# Epoch 10/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0068 - huber_loss: 0.0068
# Epoch 11/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0036 - huber_loss: 0.0036
# Epoch 12/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0040 - huber_loss: 0.0040
# Epoch 13/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0053 - huber_loss: 0.0053
# Epoch 14/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0053 - huber_loss: 0.0053
# Epoch 15/15
# 108/108 [==============================] - 2s 14ms/step - loss: 0.0051 - huber_loss: 0.0051

# %%
runModel(cases, 1, 'hinge')
# Out:
# Given the Array:
# [0.81449227 0.69947314 0.55561704]
# Predict this y:
#  [[0.6234954]]
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_108 (LSTM)             (None, 12, 100)           40800
#
#  dropout_70 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_70 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_109 (LSTM)             (None, 12, 50)            30200
#
#  dropout_71 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_71 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_110 (LSTM)             (None, 25)                7600
#
#  dense_37 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,226
# Trainable params: 78,926
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 5s 14ms/step - loss: 0.5164 - hinge: 0.5164
# Epoch 2/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2942 - hinge: 0.2942
# Epoch 3/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2716 - hinge: 0.2716
# Epoch 4/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2407 - hinge: 0.2407
# Epoch 5/15
# 108/108 [==============================] - 1s 14ms/step - loss: 0.2794 - hinge: 0.2794
# Epoch 6/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2323 - hinge: 0.2323
# Epoch 7/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2905 - hinge: 0.2905
# Epoch 8/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2576 - hinge: 0.2576
# Epoch 9/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2877 - hinge: 0.2877
# Epoch 10/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.2506 - hinge: 0.2506
# Epoch 11/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2564 - hinge: 0.2564
# Epoch 12/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2643 - hinge: 0.2643
# Epoch 13/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2502 - hinge: 0.2502
# Epoch 14/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2628 - hinge: 0.2628
# Epoch 15/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.2450 - hinge: 0.2450

# %%
vaccinations = pd.read_csv('./../Data/Final_Datasets/country_vaccinations.csv')

vaccinations = vaccinations[vaccinations['country'] == 'United States']

# print(vaccinations)

period_start = vaccinations.iloc[0]['date']
period_end = vaccinations.iloc[len(vaccinations) - 1]['date']

cases = pd.read_csv('./../Data/Final_Datasets/country_death_case.csv',
                 index_col='Date_reported',
                 parse_dates=True)

cases = cases[cases['Country'] == 'United States of America']

cases = cases.loc[period_start:period_end]

# trim the cases to the dates of the vaccinations
cases = cases['New_cases']
cases = pd.DataFrame(cases)
cases.insert(1, "daily_vaccinations", vaccinations["daily_vaccinations"].tolist(), True)
# cases = cases.tail(150)

# %%
runModel(cases, 2, 'mse')
# Out:
# Given the Array:
# [0.81449227 0.         0.69947314 0.00130569 0.55561704 0.00774888]
# Predict this y:
#  [[0.6234954  0.02036522]]
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_111 (LSTM)             (None, 12, 100)           41200
#
#  dropout_72 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_72 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_112 (LSTM)             (None, 12, 50)            30200
#
#  dropout_73 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_73 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_113 (LSTM)             (None, 25)                7600
#
#  dense_38 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,626
# Trainable params: 79,326
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 6s 15ms/step - loss: 0.1592 - mse: 0.1592
# Epoch 2/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0937 - mse: 0.0937
# Epoch 3/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0930 - mse: 0.0930
# Epoch 4/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0864 - mse: 0.0864
# Epoch 5/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0855 - mse: 0.0855
# Epoch 6/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0847 - mse: 0.0847
# Epoch 7/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0859 - mse: 0.0859
# Epoch 8/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0837 - mse: 0.0837
# Epoch 9/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0823 - mse: 0.0823
# Epoch 10/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0845 - mse: 0.0845
# Epoch 11/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0836 - mse: 0.0836
# Epoch 12/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0816 - mse: 0.0816
# Epoch 13/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0822 - mse: 0.0822
# Epoch 14/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0825 - mse: 0.0825
# Epoch 15/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0819 - mse: 0.0819

# %%
runModel(cases, 2, Huber())
# Out:
# Given the Array:
# [0.81449227 0.         0.69947314 0.00130569 0.55561704 0.00774888]
# Predict this y:
#  [[0.6234954  0.02036522]]
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_114 (LSTM)             (None, 12, 100)           41200
#
#  dropout_74 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_74 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_115 (LSTM)             (None, 12, 50)            30200
#
#  dropout_75 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_75 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_116 (LSTM)             (None, 25)                7600
#
#  dense_39 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,626
# Trainable params: 79,326
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 5s 15ms/step - loss: 0.0762 - huber_loss: 0.0762
# Epoch 2/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0521 - huber_loss: 0.0521
# Epoch 3/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0463 - huber_loss: 0.0463
# Epoch 4/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0455 - huber_loss: 0.0455
# Epoch 5/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0433 - huber_loss: 0.0433
# Epoch 6/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0435 - huber_loss: 0.0435
# Epoch 7/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0437 - huber_loss: 0.0437
# Epoch 8/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0421 - huber_loss: 0.0421
# Epoch 9/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0417 - huber_loss: 0.0417
# Epoch 10/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0411 - huber_loss: 0.0411
# Epoch 11/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0412 - huber_loss: 0.0412
# Epoch 12/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0413 - huber_loss: 0.0413
# Epoch 13/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0415 - huber_loss: 0.0415
# Epoch 14/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0413 - huber_loss: 0.0413
# Epoch 15/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0409 - huber_loss: 0.0409

# %%
def generateVacData(gap):
    vaccinations = pd.read_csv('./../Data/Final_Datasets/country_vaccinations.csv')

    vaccinations = vaccinations[vaccinations['country'] == 'United States']

    # print(vaccinations)

    period_start = vaccinations.iloc[0]['date']
    period_end = vaccinations.iloc[len(vaccinations) - 1]['date']

    cases = pd.read_csv('./../Data/Final_Datasets/country_death_case.csv',
                     index_col='Date_reported',
                     parse_dates=True)

    cases = cases[cases['Country'] == 'United States of America']

    cases = cases.loc[period_start:period_end]

    if (gap < 0):
        cases, vaccinations = applyGap(gap, cases, vaccinations)

    # trim the cases to the dates of the vaccinations
    cases = cases['New_cases']
    cases = pd.DataFrame(cases)
    cases.insert(1, "daily_vaccinations", vaccinations["daily_vaccinations"].tolist(), True)
    
    return cases

# %%
cases = generateVacData(14)
runModel(cases, 2, 'mse')
# Out:
# Given the Array:
# [0.81652933 0.         0.67534422 0.2753667  0.62529086 0.32342022]
# Predict this y:
#  [[1.         0.37539227]]
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_123 (LSTM)             (None, 12, 100)           41200
#
#  dropout_80 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_80 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_124 (LSTM)             (None, 12, 50)            30200
#
#  dropout_81 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_81 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_125 (LSTM)             (None, 25)                7600
#
#  dense_42 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,626
# Trainable params: 79,326
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 5s 13ms/step - loss: 0.1748 - mse: 0.1748
# Epoch 2/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1246 - mse: 0.1246
# Epoch 3/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1209 - mse: 0.1209
# Epoch 4/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.1185 - mse: 0.1185
# Epoch 5/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1122 - mse: 0.1122
# Epoch 6/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1121 - mse: 0.1121
# Epoch 7/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1095 - mse: 0.1095
# Epoch 8/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1085 - mse: 0.1085
# Epoch 9/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1079 - mse: 0.1079
# Epoch 10/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.1083 - mse: 0.1083
# Epoch 11/15
# 108/108 [==============================] - 1s 14ms/step - loss: 0.1067 - mse: 0.1067
# Epoch 12/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.1066 - mse: 0.1066
# Epoch 13/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.1067 - mse: 0.1067
# Epoch 14/15
# 108/108 [==============================] - 1s 14ms/step - loss: 0.1069 - mse: 0.1069
# Epoch 15/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.1068 - mse: 0.1068

# %%
cases = generateVacData(14)
runModel(cases, 2, Huber())
# Out:
# Given the Array:
# [0.81652933 0.         0.67534422 0.2753667  0.62529086 0.32342022]
# Predict this y:
#  [[1.         0.37539227]]
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_120 (LSTM)             (None, 12, 100)           41200
#
#  dropout_78 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_78 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_121 (LSTM)             (None, 12, 50)            30200
#
#  dropout_79 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_79 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_122 (LSTM)             (None, 25)                7600
#
#  dense_41 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,626
# Trainable params: 79,326
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 6s 14ms/step - loss: 0.0964 - huber_loss: 0.0964
# Epoch 2/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0728 - huber_loss: 0.0728
# Epoch 3/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0631 - huber_loss: 0.0631
# Epoch 4/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0579 - huber_loss: 0.0579
# Epoch 5/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0559 - huber_loss: 0.0559
# Epoch 6/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0565 - huber_loss: 0.0565
# Epoch 7/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0550 - huber_loss: 0.0550
# Epoch 8/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0556 - huber_loss: 0.0556
# Epoch 9/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0536 - huber_loss: 0.0536
# Epoch 10/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0541 - huber_loss: 0.0541
# Epoch 11/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0535 - huber_loss: 0.0535
# Epoch 12/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0539 - huber_loss: 0.0539
# Epoch 13/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0533 - huber_loss: 0.0533
# Epoch 14/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0534 - huber_loss: 0.0534
# Epoch 15/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0528 - huber_loss: 0.0528

# %%
gaps = [0, 1, 5, 10, 14, 21, 30, 45, 60]

for gap in gaps:
    cases = generateVacData(gap)
    print("Running with gap of " + str(gap))
    runModel(cases, 2, Huber())
# Out:
# Running with gap of 0
# Given the Array:
# [0.81652933 0.         0.67534422 0.2753667  0.62529086 0.32342022]
# Predict this y:
#  [[1.         0.37539227]]
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_126 (LSTM)             (None, 12, 100)           41200
#
#  dropout_82 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_82 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_127 (LSTM)             (None, 12, 50)            30200
#
#  dropout_83 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_83 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_128 (LSTM)             (None, 25)                7600
#
#  dense_43 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,626
# Trainable params: 79,326
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 5s 14ms/step - loss: 0.0930 - huber_loss: 0.0930
# Epoch 2/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0657 - huber_loss: 0.0657
# Epoch 3/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0598 - huber_loss: 0.0598
# Epoch 4/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0597 - huber_loss: 0.0597
# Epoch 5/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0551 - huber_loss: 0.0551
# Epoch 6/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0554 - huber_loss: 0.0554
# Epoch 7/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0545 - huber_loss: 0.0545
# Epoch 8/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0552 - huber_loss: 0.0552
# Epoch 9/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0547 - huber_loss: 0.0547
# Epoch 10/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0548 - huber_loss: 0.0548
# Epoch 11/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0543 - huber_loss: 0.0543
# Epoch 12/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0542 - huber_loss: 0.0542
# Epoch 13/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0541 - huber_loss: 0.0541
# Epoch 14/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0535 - huber_loss: 0.0535
# Epoch 15/15
# 108/108 [==============================] - 1s 14ms/step - loss: 0.0531 - huber_loss: 0.0531
# Running with gap of 1
# Given the Array:
# [0.81652933 0.         0.67534422 0.2753667  0.62529086 0.32342022]
# Predict this y:
#  [[1.         0.37539227]]
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_129 (LSTM)             (None, 12, 100)           41200
#
#  dropout_84 (Dropout)        (None, 12, 100)           0
#
#  batch_normalization_84 (Bat  (None, 12, 100)          400
#  chNormalization)
#
#  lstm_130 (LSTM)             (None, 12, 50)            30200
#
#  dropout_85 (Dropout)        (None, 12, 50)            0
#
#  batch_normalization_85 (Bat  (None, 12, 50)           200
#  chNormalization)
#
#  lstm_131 (LSTM)             (None, 25)                7600
#
#  dense_44 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 79,626
# Trainable params: 79,326
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/15
# 108/108 [==============================] - 7s 17ms/step - loss: 0.0958 - huber_loss: 0.0958
# Epoch 2/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0650 - huber_loss: 0.0650
# Epoch 3/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0580 - huber_loss: 0.0580
# Epoch 4/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0560 - huber_loss: 0.0560
# Epoch 5/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0566 - huber_loss: 0.0566
# Epoch 6/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0556 - huber_loss: 0.0556
# Epoch 7/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0548 - huber_loss: 0.0548
# Epoch 8/15
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0543 - huber_loss: 0.0543
# Epoch 9/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0542 - huber_loss: 0.0542
# Epoch 10/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0540 - huber_loss: 0.0540
# Epoch 11/15
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0534 - huber_loss: 0.0534
# Epoch 12/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0534 - huber_loss: 0.0534
# Epoch 13/15
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0538 - huber_loss: 0.0538
# Epoch 14/15
#  56/108 [==============>...............] - ETA: 0s - loss: 0.0576 - huber_loss: 0.0576

# %%
def generateVacDeathData(gap):
    vaccinations = pd.read_csv('./../Data/Final_Datasets/country_vaccinations.csv')

    vaccinations = vaccinations[vaccinations['country'] == 'United States']

    # print(vaccinations)

    period_start = vaccinations.iloc[0]['date']
    period_end = vaccinations.iloc[len(vaccinations) - 1]['date']

    cases = pd.read_csv('./../Data/Final_Datasets/country_death_case.csv',
                     index_col='Date_reported',
                     parse_dates=True)

    cases = cases[cases['Country'] == 'United States of America']

    cases = cases.loc[period_start:period_end]

    if (gap < 0):
        cases, vaccinations = applyGap(gap, cases, vaccinations)

    # trim the cases to the dates of the vaccinations
    cases = cases['New_cases']
    cases = pd.DataFrame(cases)
    cases.insert(1, "daily_vaccinations", vaccinations["daily_vaccinations"].tolist(), True)
    
    return cases
